# %% [markdown]
# ## 공공데이터를 이용한 지역별 브랜드별 카페 정보 확인(2021)
#
# **처리 목적**
#
# - 공공데이터에서 관련 데이터를 수집해 카페업종의 현황을 확인
#
#
# **명세사항**
#
# 1. 전국 카페 데이터를 모두 수집
# 2. 지역별 or 브랜드별 점포 현황을 확인
# 3. 결과를 시각화
#
#
#
# [데이터] https://www.data.go.kr/data/15083033/fileData.do

# %%
# 라이브러리를 불러옵니다.
import pandas as pd
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
import os
curpath =os.getcwd()
curpath
# Out:
# 'C:\\Users\\gg664\\AppData\\Local\\Programs\\Python\\Python38\\Scripts\\0716.브랜드별카페'

# %%
# 다운로드 받은 데이터중 일부를 열어봅니다.
temp = pd.read_csv("./data/소상공인시장진흥공단_상가(상권)정보_경기_202103.csv", sep=',',
                  encoding='utf-8')
temp.head(5)
# Out:
#      상가업소번호      상호명    지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 0  17174132       스푼    NaN         Q       음식       Q01       한식    Q01A01
# 1  17174088      동해안    NaN         Q       음식       Q01       한식    Q01A01
# 2  17174081      하오츠    NaN         Q       음식       Q01       한식    Q01A01
# 3  20713599  눈높이러닝센타    NaN         R    학문/교육       R13   학문교육기타    R13A01
# 4  20642964     유니베라  구성대리점         D       소매       D16    화장품소매    D16A01
#
#     상권업종소분류명 표준산업분류코드        표준산업분류명  시도코드  시도명  시군구코드     시군구명       행정동코드  \
# 0  한식/백반/한정식   I56111        한식 음식점업    41  경기도  41480      파주시  4148053000
# 1  한식/백반/한정식   I56111        한식 음식점업    41  경기도  41480      파주시  4148051000
# 2  한식/백반/한정식   I56111        한식 음식점업    41  경기도  41480      파주시  4148026200
# 3      학습지보급   P85503       방문 교육 학원    41  경기도  41210      광명시  4121054000
# 4     화장품판매점   G47813  화장품 및 방향제 소매업    41  경기도  41463  용인시 기흥구  4146356000
#
#    행정동명       법정동코드 법정동명                 지번코드  대지구분코드 대지구분명  지번본번지  지번부번지  \
# 0  금촌3동  4148010100  금촌동  4148010100204240049       1    대지    424   49.0
# 1  금촌1동  4148010100  금촌동  4148010100207680005       1    대지    768    5.0
# 2   조리읍  4148026225  조리읍  4148026225203860011       1    대지    386   11.0
# 3  광명3동  4121010100  광명동  4121010100201490006       1    대지    149    6.0
# 4   구성동  4146311200  언남동  4146311200203740000       1    대지    374    NaN
#
#                      지번주소         도로명코드                  도로명  건물본번지  건물부번지  \
# 0      경기도 파주시 금촌동 424-49  414804418712          경기도 파주시 정담길    105    NaN
# 1       경기도 파주시 금촌동 768-5  414804418199         경기도 파주시 마무리길      9    NaN
# 2  경기도 파주시 조리읍 오산리 386-11  414803206024      경기도 파주시 조리읍 등원로    271    NaN
# 3       경기도 광명시 광명동 149-6  412103000022          경기도 광명시 오리로    946    NaN
# 4     경기도 용인시 기흥구 언남동 374  414634412059  경기도 용인시 기흥구 구성로64번길      1    NaN
#
#                       건물관리번호     건물명                  도로명주소     구우편번호  \
# 0  4148010100104240049033496     NaN        경기도 파주시 정담길 105  413010.0
# 1  4148010100107680005026340     NaN         경기도 파주시 마무리길 9  413808.0
# 2  4148026225103860011034555  관산도어건축    경기도 파주시 조리읍 등원로 271  413821.0
# 3  4121010100101490006003352     NaN        경기도 광명시 오리로 946  423010.0
# 4  4146311200103740000023783     NaN  경기도 용인시 기흥구 구성로64번길 1  446525.0
#
#      신우편번호  동정보  층정보  호정보          경도         위도
# 0  10852.0  NaN  NaN  NaN  126.773696  37.770514
# 1  10930.0  NaN  NaN  NaN  126.778020  37.760224
# 2  10949.0  NaN    1  NaN  126.825097  37.768668
# 3  14221.0  NaN  NaN    2  126.858147  37.478530
# 4  16919.0  NaN    2  NaN  127.116575  37.294690

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508845 entries, 0 to 508844
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     508845 non-null  int64
#  1   상호명        508844 non-null  object
#  2   지점명        80797 non-null   object
#  3   상권업종대분류코드  508845 non-null  object
#  4   상권업종대분류명   508845 non-null  object
#  5   상권업종중분류코드  508845 non-null  object
#  6   상권업종중분류명   508845 non-null  object
#  7   상권업종소분류코드  508845 non-null  object
#  8   상권업종소분류명   508845 non-null  object
#  9   표준산업분류코드   477099 non-null  object
#  10  표준산업분류명    477099 non-null  object
#  11  시도코드       508845 non-null  int64
#  12  시도명        508845 non-null  object
#  13  시군구코드      508845 non-null  int64
#  14  시군구명       508845 non-null  object
#  15  행정동코드      508845 non-null  int64
#  16  행정동명       508845 non-null  object
#  17  법정동코드      508845 non-null  int64
#  18  법정동명       508845 non-null  object
#  19  지번코드       508845 non-null  int64
#  20  대지구분코드     508845 non-null  int64
#  21  대지구분명      508845 non-null  object
#  22  지번본번지      508845 non-null  int64
#  23  지번부번지      372535 non-null  float64
#  24  지번주소       508845 non-null  object
#  25  도로명코드      508845 non-null  int64
#  26  도로명        508845 non-null  object
#  27  건물본번지      508845 non-null  int64
#  28  건물부번지      99768 non-null   float64
#  29  건물관리번호     508845 non-null  object
#  30  건물명        219454 non-null  object
#  31  도로명주소      508845 non-null  object
#  32  구우편번호      507311 non-null  float64
#  33  신우편번호      508835 non-null  float64
#  34  동정보        52103 non-null   object
#  35  층정보        247544 non-null  object
#  36  호정보        119425 non-null  object
#  37  경도         508845 non-null  float64
#  38  위도         508845 non-null  float64
# dtypes: float64(6), int64(10), object(23)
# memory usage: 151.4+ MB

# %%
temp.reset_index(inplace=True, drop=True)
temp

# %%
data = temp[['상호명', '지점명', '상권업종대분류명', '상권업종중분류명', '시도명',
             '시군구명', '행정동명']]

data
